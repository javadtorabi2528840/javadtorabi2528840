# %% [markdown]
# <a href="https://colab.research.google.com/github/javadtorabi2528840/javadtorabi2528840/blob/main/blockchain_exe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import time

class BlockChain():
    # ____________difines a block chain on one machin__________

    def __init__(self):
        #__________init trx________
        self.chain = []
        self.curent_trx = []
        self.new_block(previos_hash=1 ,proof=100)
        

    def new_block(self ,proof ,previos_hash = None):
        #  ___creat a new block______
           block = {
               'index' : len(self.chain) + 1 ,
               'timeStamp' : time() ,
               'trx' : self.curent_trx ,
               'proof' : proof ,
               'previos_hash' : previos_hash or self.hash (self.chain[-1])
           }
           self.curent_trx = []
           self.chain.append (block)
           return block



    def new_trx(self, sender, recipient, amount):
        #  _________add a new trx to the mempool_________
        self.curent_trx.append({'sender' : sender , 'recipient' : recipient , 
                                'amount' : amount})
        
        return self.last_block ['index'] + 1


    @staticmethod
    def hash_bock(block):
        #  _______hash a block_________
        pass


    @property
    def last_block(self):
        #  ________return last block__________
        pass
